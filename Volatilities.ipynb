# %%
import numpy as np
import pandas as pd

# %%
portfolio =pd.read_csv('mwu_weights_return_equal_absolute_lowvol_weekly.csv',index_col=0,usecols=['Values'])
T=len(portfolio)

# %%
daily_returns = [(portfolio['Values'].iloc[i+1]/portfolio['Values'].iloc[i] -1) for i in range(T-1)]
np.std(daily_returns,ddof=1)
# Out:
# 0.024990863403339506

# %%
#mwu

for a in ['lowvol','highvol']:
    for b in ['weekly','daily','hourly']:
        for c in ['absolute','pricerel']:
            for d in ['equal','marketcap']:
                portfolio =pd.read_csv(f'mwu_weights_return_{d}_{c}_{a}_{b}.csv',index_col=0)
                T=len(portfolio)
                daily_returns = [(portfolio['Values'].iloc[i+1]/portfolio['Values'].iloc[i] -1) for i in range(T-1)]
                returns = portfolio['Values'].iloc[-1]/portfolio['Values'].iloc[0] -1
                #mwudict[a+b+c+d] = [returns,round(np.std(daily_returns,ddof=1),4)]
                print(a,b,c,d,round(np.std(daily_returns,ddof=1),4))
                #print(round(np.std(daily_returns,ddof=1),4))
# Out:
# {'lowvolweeklyabsoluteequal': [1.5582841899999997, 0.025],
#  'lowvolweeklyabsolutemarketcap': [1.4551068115651646, 0.0234],
#  'lowvolweeklypricerelequal': [1.3893291484863561, 0.0239],
#  'lowvolweeklypricerelmarketcap': [1.1382765687601304, 0.0235],
#  'lowvoldailyabsoluteequal': [1.8531406206015486, 0.0126],
#  'lowvoldailyabsolutemarketcap': [1.0382709435174409, 0.0123],
#  'lowvoldailypricerelequal': [1.7994505511139085, 0.0127],
#  'lowvoldailypricerelmarketcap': [1.0379623230032866, 0.0127],
#  'lowvolhourlyabsoluteequal': [0.037113803360515174, 0.0025],
#  'lowvolhourlyabsolutemarketcap': [0.03298518565414943, 0.0024],
#  'lowvolhourlypricerelequal': [0.03928602830413763, 0.0025],
#  'lowvolhourlypricerelmarketcap': [0.0333904038852888, 0.0024],
#  'highvolweeklyabsoluteequal': [7.086342571614402, 0.0424],
#  'highvolweeklyabsolutemarketcap': [0.9719883141681924, 0.0736],
#  'highvolweeklypricerelequal': [4.709075645569292, 0.0433],
#  'highvolweeklypricerelmarketcap': [0.9592376827304445, 0.0736],
#  'highvoldailyabsoluteequal': [8.381683800775656, 0.0193],
#  'highvoldailyabsolutemarketcap': [1.0493415292550927, 0.0355],
#  'highvoldailypricerelequal': [4.751564957657062, 0.0207],
#  'highvoldailypricerelmarketcap': [1.0290204527621643, 0.0356],
#  'highvolhourlyabsoluteequal': [0.08699724383701635, 0.0046],
#  'highvolhourlyabsolutemarketcap': [0.12346126323994944, 0.003],
#  'highvolhourlypricerelequal': [0.07012680151584405, 0.0047],
#  'highvolhourlypricerelmarketcap': [0.11824394791413728, 0.003]}

# %%
#rwma
for a in ['lowvol','highvol']:
    for b in ['weekly','daily','hourly']:
        for c in ['absolute']:
            for d in ['equal','marketcap']:
                portfolio =pd.read_csv(f'rwma_weights_return_{d}_{c}_{a}_{b}.csv',index_col=0)
                T=len(portfolio)
                daily_returns = [(portfolio['Values'].iloc[i+1]/portfolio['Values'].iloc[i] -1) for i in range(T-1)]
                #print(a,b,c,d,round(np.std(daily_returns,ddof=1),4))
                print(round(np.std(daily_returns,ddof=1),4))
# Out:
# 0.0244
# 0.0239
# 0.0118
# 0.0122
# 0.0026
# 0.0024
# 0.0421
# 0.0737
# 0.0193
# 0.0356
# 0.0046
# 0.003

# %%
#Visualize
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('fulldata.csv')
data
# Out:
#    Portfolio Algorithm Time Period  Weight Method      Loss Method  Return  \
# 0        Low       MWU       Daily  Equal weights  Absolute return  1.5256
# 1        Low       MWU       Daily     Market cap  Absolute return  0.7173
# 2        Low       MWU       Daily  Equal weights   Price relative  1.4050
# 3        Low       MWU       Daily     Market cap   Price relative  0.7539
# 4       High       MWU       Daily  Equal weights  Absolute return  7.5071
# 5       High       MWU       Daily     Market cap  Absolute return  0.4131
# 6       High       MWU       Daily  Equal weights   Price relative  3.8881
# 7       High       MWU       Daily     Market cap   Price relative  0.6228
# 8        Low      RWMA       Daily  Equal weights  Absolute return  1.2512
# 9        Low      RWMA       Daily     Market cap  Absolute return  0.6786
# 10      High      RWMA       Daily  Equal weights  Absolute return  4.9386
# 11      High      RWMA       Daily     Market cap  Absolute return  0.1248
# 12       Low       MWU      Hourly  Equal weights  Absolute return -0.0071
# 13       Low       MWU      Hourly     Market cap  Absolute return -0.0204
# 14       Low       MWU      Hourly  Equal weights   Price relative -0.0072
# 15       Low       MWU      Hourly     Market cap   Price relative -0.0125
# 16      High       MWU      Hourly  Equal weights  Absolute return  0.0192
# 17      High       MWU      Hourly     Market cap  Absolute return  0.0903
# 18      High       MWU      Hourly  Equal weights   Price relative -0.0054
# 19      High       MWU      Hourly     Market cap   Price relative  0.0900
# 20       Low      RWMA      Hourly  Equal weights  Absolute return -0.0165
# 21       Low      RWMA      Hourly     Market cap  Absolute return -0.0125
# 22      High      RWMA      Hourly  Equal weights  Absolute return -0.0446
# 23      High      RWMA      Hourly     Market cap  Absolute return  0.0455
# 24       Low       MWU      Weekly  Equal weights  Absolute return  1.4075
# 25       Low       MWU      Weekly     Market cap  Absolute return  1.2820
# 26       Low       MWU      Weekly  Equal weights   Price relative  1.2096
# 27       Low       MWU      Weekly     Market cap   Price relative  0.9855
# 28      High       MWU      Weekly  Equal weights  Absolute return  6.6566
# 29      High       MWU      Weekly     Market cap  Absolute return  0.6943
# 30      High       MWU      Weekly  Equal weights   Price relative  4.3233
# 31      High       MWU      Weekly     Market cap   Price relative  0.7813
# 32       Low      RWMA      Weekly  Equal weights  Absolute return  1.1085
# 33       Low      RWMA      Weekly     Market cap  Absolute return  0.7726
# 34       Low      RWMA      Weekly  Equal weights  Absolute return  3.8569
# 35       Low      RWMA      Weekly     Market cap  Absolute return  0.3812
#
#     Volatility  Return above market         CoV
# 0       0.0126               0.1986   15.761905
# 1       0.0123              -0.6097  -49.569106
# 2       0.0127               0.0780    6.141732
# 3       0.0127              -0.5731  -45.125984
# 4       0.0193               6.3914  331.160622
# 5       0.0355              -0.7026  -19.791549
# 6       0.0207               2.7724  133.932367
# 7       0.0356              -0.4929  -13.845506
# 8       0.0118              -0.0758   -6.423729
# 9       0.0122              -0.6484  -53.147541
# 10      0.0193               3.8229  198.077720
# 11      0.0356              -0.9909  -27.834270
# 12      0.0025              -0.0485  -19.400000
# 13      0.0024              -0.0618  -25.750000
# 14      0.0025              -0.0486  -19.440000
# 15      0.0024              -0.0539  -22.458333
# 16      0.0046              -0.0669  -14.543478
# 17      0.0030               0.0042    1.400000
# 18      0.0047              -0.0915  -19.468085
# 19      0.0030               0.0039    1.300000
# 20      0.0026              -0.0579  -22.269231
# 21      0.0024              -0.0539  -22.458333
# 22      0.0046              -0.1307  -28.413043
# 23      0.0030              -0.0406  -13.533333
# 24      0.0250               0.1042    4.168000
# 25      0.0234              -0.0213   -0.910256
# 26      0.0239              -0.0937   -3.920502
# 27      0.0235              -0.3178  -13.523404
# 28      0.0424               5.5002  129.721698
# 29      0.0736              -0.4621   -6.278533
# 30      0.0433               3.1669   73.138568
# 31      0.0736              -0.3751   -5.096467
# 32      0.0244              -0.1948   -7.983607
# 33      0.0239              -0.5307  -22.205021
# 34      0.0421               2.7005   64.144893
# 35      0.0737              -0.7752  -10.518318

# %%
fig,ax = plt.subplots()
colors = ['blue','orange']
for i,val in enumerate(['MWU','RWMA']):
    x = data['Volatility'][data['Algorithm']==val]
    y = data['Return above market'][data['Algorithm']==val]
    ax.scatter(x,y,c=colors[i],label=val)

ax.legend()
ax.set_title('Return vs. Volatility')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')

# %%
fig,ax = plt.subplots()
colors = ['blue','gray','green']
for i,val in enumerate(['Daily','Weekly','Hourly']):
    x = data['Volatility'][data['Time Period']==val]
    y = data['Return above market'][data['Time Period']==val]
    ax.scatter(x,y,c=colors[i],label=val)

ax.legend()
ax.set_title('Return vs. Volatility')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')

# %%
fig,ax = plt.subplots()
colors = ['#bc5090','#003f5c']
for i,val in enumerate(['Equal weights','Market cap']):
    x = data['Volatility'][data['Weight Method']==val]
    y = data['Return above market'][data['Weight Method']==val]
    ax.scatter(x,y,c=colors[i],label=val)

ax.legend()
ax.set_title('Return vs. Volatility')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')

# %%
fig,ax = plt.subplots()
colors = ['#0d9365','#ffa600']
for i,val in enumerate(['Absolute return','Price relative']):
    x = data['Volatility'][data['Loss Method']==val]
    y = data['Return above market'][data['Loss Method']==val]
    ax.scatter(x,y,c=colors[i],label=val)

ax.legend()
ax.set_title('Return vs. Volatility')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')

# %%
fig,ax = plt.subplots()
colors = ['blue','black']
for i,val in enumerate(['Low','High']):
    x = data['Volatility'][data['Portfolio']==val]
    y = data['Return above market'][data['Portfolio']==val]
    ax.scatter(x,y,c=colors[i],label=val+' Vol Portfolio')

ax.legend()
ax.set_title('Return vs. Volatility')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')

# %%
fig,ax = plt.subplots()
colors = ['pink','purple']
for i,val in enumerate(['Equal weights','Market cap']):
    x = data['Volatility'][data['Weight Method']==val][data['Time Period']=='Hourly']
    y = data['Return above market'][data['Weight Method']==val][data['Time Period']=='Hourly']
    ax.scatter(x,y,c=colors[i],label=val)

ax.legend()
ax.set_title('Return vs. Volatility: Hourly')
ax.set_xlabel('Volatility')
ax.set_ylabel('Return above market')
ax.axhline(y=0)
#ax.spines['bottom'].set_position('zero')
